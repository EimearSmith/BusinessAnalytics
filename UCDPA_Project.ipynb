# %% [markdown]
# # Irish Property Prices 2010-2021

# %%
# Importing packages that will be used for this project
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Import a CSV file as a Pandas Dataframe.
import pandas as pd
House_Prices=pd.read_csv("Property_Price_Register_Ireland-28-05-2021.csv")
print(House_Prices.head())
# Out:
#     SALE_DATE                                         ADDRESS POSTAL_CODE  \
# 0  2010-01-01          5 Braemor Drive, Churchtown, Co.Dublin         NaN
# 1  2010-01-03  134 Ashewood Walk, Summerhill Lane, Portlaoise         NaN
# 2  2010-01-04             1 Meadow Avenue, Dundrum, Dublin 14         NaN
# 3  2010-01-04                         1 The Haven, Mornington         NaN
# 4  2010-01-04                   11 Melville Heights, Kilkenny         NaN
#
#      COUNTY  SALE_PRICE  IF_MARKET_PRICE  IF_VAT_EXCLUDED  \
# 0    Dublin    343000.0                0                0
# 1     Laois    185000.0                0                1
# 2    Dublin    438500.0                0                0
# 3     Meath    400000.0                0                0
# 4  Kilkenny    160000.0                0                0
#
#                            PROPERTY_DESC  \
# 0  Second-Hand Dwelling house /Apartment
# 1          New Dwelling house /Apartment
# ...

# %%
# Pull in entire data from CSV which shows there are 476,745 rows and 9 columns
House_Prices
# Out:
#          SALE_DATE                                         ADDRESS  \
# 0       2010-01-01          5 Braemor Drive, Churchtown, Co.Dublin
# 1       2010-01-03  134 Ashewood Walk, Summerhill Lane, Portlaoise
# 2       2010-01-04             1 Meadow Avenue, Dundrum, Dublin 14
# 3       2010-01-04                         1 The Haven, Mornington
# 4       2010-01-04                   11 Melville Heights, Kilkenny
# ...            ...                                             ...
# 476740  2021-05-28                GRANGE STORES, GRANGE, MULLINGAR
# 476741  2021-05-28               MAIN STREET, LOWER BORRIS, BORRIS
# 476742  2021-05-28                         MULTYFARNHAM, WESTMEATH
# 476743  2021-05-28             NO 2 RIVERLODGE, SHRONE, GLENGARIFF
# 476744  2021-05-28                         RABANE, KILL, COOTEHILL
#
#        POSTAL_CODE     COUNTY  SALE_PRICE  IF_MARKET_PRICE  IF_VAT_EXCLUDED  \
# 0              NaN     Dublin    343000.0                0                0
# ...

# %%
#here we can explore the DataFrame and see what address has the most number of sales
House_Prices.groupby(['ADDRESS']).count()['COUNTY'].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7324/2244984701.py in <module>
#       1 #here we can explore the DataFrame and see what address has the most number of sales
# ----> 2 House_Prices.groupby(['ADDRESS']).count()['COUNTY'].sort_values(ascending=False)
#
# NameError: name 'House_Prices' is not defined

# %%
#Another groupby on different colums shows us that despite the more houses sold in Midleton, the highest average price was in Dublin
House_Prices.groupby(['COUNTY']).mean()['SALE_PRICE'].sort_values(ascending=False)
# Out:
# COUNTY
# Dublin       411673.133249
# Wicklow      313417.348772
# Kildare      266907.150575
# Meath        240936.761231
# Cork         228345.737261
# Galway       204995.368932
# Louth        184573.129254
# Kilkenny     182505.254472
# Limerick     169921.912492
# Kerry        160922.120121
# Wexford      160460.974556
# Clare        159339.057546
# Waterford    158441.593287
# Westmeath    153336.871621
# Carlow       152975.334509
# Laois        151141.607792
# Tipperary    138955.057643
# Offaly       138931.041310
# Sligo        134606.595291
# Monaghan     131342.191390
# Mayo         127757.083553
# Cavan        118877.039582
# Donegal      117704.793719
# Roscommon    104402.824000
# Leitrim      101450.042856
# Longford      98250.340081
# Name: SALE_PRICE, dtype: float64

# %%
# We can then check the Datframe for missing values:
House_Prices.isna().sum()
# Out:
# SALE_DATE             0
# ADDRESS               0
# POSTAL_CODE           0
# COUNTY                0
# SALE_PRICE            0
# IF_MARKET_PRICE       0
# IF_VAT_EXCLUDED       0
# PROPERTY_DESC         0
# PROPERTY_SIZE_DESC    0
# dtype: int64

# %%
# Then we drop the missing values as follows:
House_Prices = House_Prices.dropna()
House_Prices
# Out:
#          SALE_DATE                                            ADDRESS  \
# 47      2010-01-05   134 longboat quay north, sir john rogersons quay
# 56      2010-01-05               3 Myrtle Square, The Coast, Baldoyle
# 170     2010-01-08        4 Streamville Close, Donaghmeade, Dublin 13
# 192     2010-01-08          APT 8  1 GRANGE LODGE AVENUE, CLONGRIFFIN
# 337     2010-01-14  2 Belarmine Hall, Newtownlittle  Stepaside, Du...
# ...            ...                                                ...
# 373563  2019-06-20               14 Orwell Place, Block B, Marianella
# 391227  2019-10-01                 Apt 35 Hanover Court, Hanover Quay
# 412521  2020-02-05           13 Westminister Wood, Foxrock, Dublin 18
# 424779  2020-05-23                 6 Wood Ville, Howth Road, Clontarf
# 427094  2020-06-17  Apartment 1  Block 14, New Priory, Hole in the...
#
#        POSTAL_CODE  COUNTY  SALE_PRICE  IF_MARKET_PRICE  IF_VAT_EXCLUDED  \
# ...

# %%
drop_columns = House_Prices.dropna(axis=0)
(drop_columns.shape)
# Out:
# (7952, 9)

# %%
drop_duplicates = House_Prices.drop_duplicates
