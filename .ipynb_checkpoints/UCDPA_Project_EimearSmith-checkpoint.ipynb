# %%
Forbes_2022

# %%
# Importing packages that will be used for this project
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Import a CSV file as a Pandas Dataframe.
import pandas as pd
forbes_2022=pd.read_csv("forbes_2022_billionaires.csv")
print(forbes_2022.head())
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %%
# Pull in entire data from CSV which shows there are 2668 rows and 22 columns
forbes_2022
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
#Next we check for missing data as follows
forbes_2022.isna().sum()
# Out:
# rank                       0
# personName                 0
# age                       86
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# country                   13
# state                   1920
# city                      44
# countryOfCitizenship       0
# organization            2316
# selfMade                   0
# gender                    16
# birthDate                 99
# title                   2267
# philanthropyScore       2272
# residenceMsa            2029
# numberOfSiblings        2541
# bio                        0
# about                   1106
# dtype: int64

# %%
#The we remove all rows with missing values
data_cleaned=forbes_2022.dropna()
data_cleaned.isna().sum()
# Out:
# rank                    0
# personName              0
# age                     0
# finalWorth              0
# year                    0
# month                   0
# category                0
# source                  0
# country                 0
# state                   0
# city                    0
# countryOfCitizenship    0
# organization            0
# selfMade                0
# gender                  0
# birthDate               0
# title                   0
# philanthropyScore       0
# residenceMsa            0
# numberOfSiblings        0
# bio                     0
# about                   0
# dtype: int64

# %%
#We can now check how much of the null data
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 37 to 1304
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  5 non-null      int64
#  1   personName            5 non-null      object
#  2   age                   5 non-null      float64
#  3   finalWorth            5 non-null      float64
#  4   year                  5 non-null      int64
#  5   month                 5 non-null      int64
#  6   category              5 non-null      object
#  7   source                5 non-null      object
#  8   country               5 non-null      object
#  9   state                 5 non-null      object
#  10  city                  5 non-null      object
#  11  countryOfCitizenship  5 non-null      object
#  12  organization          5 non-null      object
#  13  selfMade              5 non-null      bool
#  14  gender                5 non-null      object
# ...
